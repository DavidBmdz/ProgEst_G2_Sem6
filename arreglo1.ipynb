# %%
vector = []
vector.append(8)
vector.append(9)
vector.append(11)
print(vector)
print(vector[0])
print(vector[1])
print(vector[2])
#Imprime el ultimo elemento del vector
print(vector[-1])
print(vector[-2])
print(vector[-3])
# Out:
# [8, 9, 11]
# 8
# 9
# 11
# 11
# 9
# 8

# %%
#Arreglo de diferentes tipos de datos
vector2.insert(1, "Managua")
print(vector2)
# Out:
# [3, 'Managua', 4, 56, 'Luis']

# %%
#Recorrer el vector
for item in vector2:
    print(item)
# Out:
# 3
# Managua
# 4
# 56
# Luis
